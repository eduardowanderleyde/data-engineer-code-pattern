# %% [markdown]
# # Introduction to Pandas: Series and DataFrames

# %%
# !pip install numpy
# Out:
# ...
#      ---------------------------------------- 13.1/13.1 MB 8.3 MB/s eta 0:00:00
# ...
# [notice] A new release of pip available: 22.3 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# !pip install matplotlib
# Out:
# ...
#      ---------------------------------------- 8.1/8.1 MB 8.1 MB/s eta 0:00:00
# ...
#      -------------------------------------- 225.2/225.2 kB 6.9 MB/s eta 0:00:00
# ...
#      ---------------------------------------- 2.3/2.3 MB 9.1 MB/s eta 0:00:00
# ...
#      ---------------------------------------- 73.8/73.8 kB ? eta 0:00:00
# ...
#      ---------------------------------------- 7.0/7.0 MB 9.9 MB/s eta 0:00:00
# ...
#      -------------------------------------- 113.9/113.9 kB 6.9 MB/s eta 0:00:00
# ...
# [notice] A new release of pip available: 22.3 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# !pip install pandas
# Out:
# ...
#      ---------------------------------------- 11.3/11.3 MB 8.7 MB/s eta 0:00:00
# ...
#      ------------------------------------- 509.2/509.2 kB 10.6 MB/s eta 0:00:00
# ...
#      ------------------------------------- 347.8/347.8 kB 10.9 MB/s eta 0:00:00
# ...
# [notice] A new release of pip available: 22.3 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# Out:
# Matplotlib is building the font cache; this may take a moment.

# %%
# Configuration to display more columns
pd.set_option('display.max_columns', None)

# %%
# 1. Series - a one-dimensional structure similar to an array or list
print("1. Working with Series")
print("-" * 50)

# Creating a Series from a list
list = [10, 20, 30, 40, 50]
s1 = pd.Series(list)
print("Series created from a list:")
print(s1)
print()
# Out:
# 1. Working with Series
# --------------------------------------------------
# Series created from a list:
# 0    10
# 1    20
# 2    30
# 3    40
# 4    50
# dtype: int64

# %%
# Creating a Series with custom indices
s2 = pd.Series([10, 20, 30, 40, 50], index=['a', 'b', 'c', 'd', 'e'])
print("Series with custom indices:")
print(s2)
# Out:
# Series with custom indices:
# a    10
# b    20
# c    30
# d    40
# e    50
# dtype: int64

# %%
# Creating a Series from a Dictionary
dictionary = {'a': 10, 'b': 20, 'c': 30, 'd': 40, 'e': 50}
s3 = pd.Series(dictionary)
print("Series created from a dictionary:")
print(s3)
print()
# Out:
# Series created from a dictionary:
# a    10
# b    20
# c    30
# d    40
# e    50
# dtype: int64

# %%
# Accessing elements of a Series
print("Accessing elements of the Series:")
print("Element at index 'a':", s3['a'])
print("Elements at indices 'a', 'c' and 'e':", s3[['a', 'c', 'e']])
print()
# Out:
# Accessing elements of the Series:
# Element at index 'a': 10
# Elements at indices 'a', 'c' and 'e': a    10
# c    30
# e    50
# dtype: int64

# %%
# Series Operations
print("Series Operations:")
print("s2 + 5:")
print(s2 + 5)
print("\ns2 * 2:")
print(s2 * 2)
print()
# Out:
# Series Operations:
# s2 + 5:
# a    15
# b    25
# c    35
# d    45
# e    55
# dtype: int64
#
# s2 * 2:
# a     20
# b     40
# c     60
# d     80
# e    100
# dtype: int64

# %%
# 2. DataFrames - a two-dimensional structure similar to a table
print("2. Working with DataFrames")
print("-" * 50)
# Out:
# 2. Working with DataFrames
# --------------------------------------------------

# %%
# Creating a DataFrame from a Dictionary
data = {
    'Name': ['Ana', 'Bruno', 'Carlos', 'Daniela', 'Eduardo'],
    'Age': [25, 30, 35, 40, 45],
    'City': ['São Paulo', 'Rio de Janeiro', 'Belo Horizonte', 'Curitiba', 'Salvador'],
    'Salary': [5000, 6000, 7000, 8000, 9000]
}

df1 = pd.DataFrame(data)
print("DataFrame created from a dictionary:")
print(df1)
print()
# Out:
# DataFrame created from a dictionary:
#       Name  Age            City  Salary
# 0      Ana   25       São Paulo    5000
# 1    Bruno   30  Rio de Janeiro    6000
# 2   Carlos   35  Belo Horizonte    7000
# 3  Daniela   40        Curitiba    8000
# 4  Eduardo   45        Salvador    9000

# %%
# DataFrame Information
print("DataFrame Information:")
print("Shape (rows, columns):", df1.shape)
print("\nData Types:")
print(df1.dtypes)
print("\nFirst 3 rows:")
print(df1.head(3))
print("\nLast 2 rows:")
print(df1.tail(2))
print("\nStatistical summary of numeric columns:")
print(df1.describe())
print()
# Out:
# DataFrame Information:
# Shape (rows, columns): (5, 4)
#
# Data Types:
# Name      object
# Age        int64
# City      object
# Salary     int64
# dtype: object
#
# First 3 rows:
#      Name  Age            City  Salary
# 0     Ana   25       São Paulo    5000
# 1   Bruno   30  Rio de Janeiro    6000
# 2  Carlos   35  Belo Horizonte    7000
#
# Last 2 rows:
#       Name  Age      City  Salary
# 3  Daniela   40  Curitiba    8000
# 4  Eduardo   45  Salvador    9000
#
# Statistical summary of numeric columns:
#              Age      Salary
# count   5.000000     5.00000
# mean   35.000000  7000.00000
# std     7.905694  1581.13883
# min    25.000000  5000.00000
# 25%    30.000000  6000.00000
# 50%    35.000000  7000.00000
# 75%    40.000000  8000.00000
# max    45.000000  9000.00000

# %%
# Accessing DataFrame Data
print("Accessing DataFrame Data:")
print("Column 'Name':")
print(df1['Name'])
print("\nColumns 'Name' and 'Age':")
print(df1[['Name', 'Age']])
print("\nFirst row:")
print(df1.iloc[0])
print("\nRows 1 to 3:")
print(df1.iloc[1:4])
print("\nValue in row 2, column 'Salary':")
print(df1.iloc[2, 3]) # or df1.loc[2, 'Salary']
print()
# Out:
# Accessing DataFrame Data:
# Column 'Name':
# 0        Ana
# 1      Bruno
# 2     Carlos
# 3    Daniela
# 4    Eduardo
# Name: Name, dtype: object
#
# Columns 'Name' and 'Age':
#       Name  Age
# 0      Ana   25
# 1    Bruno   30
# 2   Carlos   35
# 3  Daniela   40
# 4  Eduardo   45
#
# First row:
# Name            Ana
# Age              25
# City      São Paulo
# Salary         5000
# Name: 0, dtype: object
#
# Rows 1 to 3:
#       Name  Age            City  Salary
# 1    Bruno   30  Rio de Janeiro    6000
# 2   Carlos   35  Belo Horizonte    7000
# 3  Daniela   40        Curitiba    8000
#
# Value in row 2, column 'Salary':
# 7000

# %%
# Data Filtering
print("Data Filtering:")
print("People older than 30:")
print(df1[df1['Age'] > 30])
print("\nPeople from São Paulo or Salvador:")
print(df1[df1['City'].isin(['São Paulo', 'Salvador'])])
print()
# Out:
# Data Filtering:
# People older than 30:
#       Name  Age            City  Salary
# 2   Carlos   35  Belo Horizonte    7000
# 3  Daniela   40        Curitiba    8000
# 4  Eduardo   45        Salvador    9000
#
# People from São Paulo or Salvador:
#       Name  Age       City  Salary
# 0      Ana   25  São Paulo    5000
# 4  Eduardo   45   Salvador    9000

# %%
# Creating new columns
print("Creating new columns:")
df1['Age Range'] = ['Young' if age < 30 else 'Adult' if age < 40 else 'Senior' for age in df1['Age']]
df1['Bonus'] = df1['Salary'] * 0.1
print(df1)
print()
# Out:
# Creating new columns:
#       Name  Age            City  Salary Age Range  Bonus
# 0      Ana   25       São Paulo    5000     Young  500.0
# 1    Bruno   30  Rio de Janeiro    6000     Adult  600.0
# 2   Carlos   35  Belo Horizonte    7000     Adult  700.0
# 3  Daniela   40        Curitiba    8000    Senior  800.0
# 4  Eduardo   45        Salvador    9000    Senior  900.0

# %%
# Data Grouping
print("Data Grouping:")
print("Average salary by age Range:")
print(df1.groupby('Age Range')['Salary'].mean())
print("\nCount by age group:")
print(df1.groupby('Age Range').size())
print()
# Out:
# Data Grouping:
# Average salary by age Range:
# Age Range
# Adult     6500.0
# Senior    8500.0
# Young     5000.0
# Name: Salary, dtype: float64
#
# Count by age group:
# Age Range
# Adult     2
# Senior    2
# Young     1
# dtype: int64

# %%
import datetime
# 3. Reading and writing data
print("3. Reading and writing data")
print("-" * 50)

def generate_random_date():
    year = np.random.randint(2020, 2025)
    month = np.random.randint(1, 13)
    day = np.random.randint(1, 28)
    return datetime.datetime(year, month, day)

# Creating a DataFrame to save
df_exemple = pd.DataFrame({
    'A': np.random.rand(5),
    'B': np.random.randint(0, 10, 5),
    'C': ['a', 'b', 'c', 'd', 'e'],
    'date': [generate_random_date() for _ in range(5)]
})

print("DataFrame for I/O demonstration:")

print(df_exemple)
print()
# Out:
# 3. Reading and writing data
# --------------------------------------------------
# DataFrame for I/O demonstration:
#           A  B  C       date
# 0  0.883763  1  a 2020-03-18
# 1  0.190530  6  b 2024-12-09
# 2  0.762798  9  c 2024-06-23
# 3  0.740068  9  d 2022-05-19
# 4  0.141581  6  e 2023-10-23

# %%
df_exemple.to_csv('exemple.csv', index=False)

# %%
with open('exemple.csv', 'r') as f:
    csv = f.read()

print(csv)
# Out:
# A,B,C,date
# 0.8837626791586979,1,a,2020-03-18
# 0.1905302607982189,6,b,2024-12-09
# 0.7627977886282468,9,c,2024-06-23
# 0.7400677534665149,9,d,2022-05-19
# 0.1415812627048766,6,e,2023-10-23

# %%
df_csv = pd.read_csv('exemple.csv')
df_csv
# Out:
#           A  B  C        date
# 0  0.883763  1  a  2020-03-18
# 1  0.190530  6  b  2024-12-09
# 2  0.762798  9  c  2024-06-23
# 3  0.740068  9  d  2022-05-19
# 4  0.141581  6  e  2023-10-23

# %%
# Saving in different formats (commented out to avoid creating files)
print("Examples of how to save DataFrames (commented code):")
print("# Save as CSV")
print("# df_example.to_csv('example.csv', index=False)")
print("\n# Save as Excel")
print("# df_example.to_excel('example.xlsx', index=False)")
print("\n# Save as JSON")
print("# df_example.to_json('example.json')")
print()

print("Examples of how to read files (commented code):")
print("# Read CSV")
print("# df_csv = pd.read_csv('example.csv')")
print("\n# Read Excel")
print("# df_excel = pd.read_excel('example.xlsx')")
print("\n# Read JSON")
print("# df_json = pd.read_json('example.json')")
print()
# Out:
# Examples of how to save DataFrames (commented code):
# # Save as CSV
# # df_example.to_csv('example.csv', index=False)
#
# # Save as Excel
# # df_example.to_excel('example.xlsx', index=False)
#
# # Save as JSON
# # df_example.to_json('example.json')
#
# Examples of how to read files (commented code):
# # Read CSV
# # df_csv = pd.read_csv('example.csv')
#
# # Read Excel
# # df_excel = pd.read_excel('example.xlsx')
#
# # Read JSON
# # df_json = pd.read_json('example.json')

# %%
# 4. Basic Data Visualization
print("4. Basic Data Visualization")
print("-" * 50)

# Creating Data for Visualization
df_vis = pd.DataFrame({
'x': range(1, 11),
'y1': np.random.rand(10) * 10,
'y2': np.random.rand(10) * 10 + 5
})

print("DataFrame for visualization:")
print(df_vis)
print()
# Out:
# 4. Basic Data Visualization
# --------------------------------------------------
# DataFrame for visualization:
#     x        y1         y2
# 0   1  6.852805  11.196806
# 1   2  5.568076  13.496041
# 2   3  1.597200  14.954319
# 3   4  7.009983   5.787023
# 4   5  4.709738   8.440312
# 5   6  1.836665  10.783043
# 6   7  4.430484   6.376367
# 7   8  8.858661  12.041600
# 8   9  4.714965   8.671164
# 9  10  8.187101  13.366925

# %%
df_vis
# Out:
#     x        y1         y2
# 0   1  6.852805  11.196806
# 1   2  5.568076  13.496041
# 2   3  1.597200  14.954319
# 3   4  7.009983   5.787023
# 4   5  4.709738   8.440312
# 5   6  1.836665  10.783043
# 6   7  4.430484   6.376367
# 7   8  8.858661  12.041600
# 8   9  4.714965   8.671164
# 9  10  8.187101  13.366925

# %%
print("To view the graphs, execute the cells below:")
print("# Line graph")
print("plt.figure(figsize=(10, 6))")
print("plt.plot(df_vis['x'], df_vis['y1'], 'b-', label='Series 1')")
print("plt.plot(df_vis['x'], df_vis['y2'], 'r--', label='Series 2')")
print("plt.title('Simple Line Graph')")
print("plt.xlabel('X-axis')")
print("plt.ylabel('Y-axis')")
print("plt.legend()")
print("plt.grid(True)")
print("plt.show()")
print()

print("# Graph of bars")
print("plt.figure(figsize=(10, 6))")
print("df1.plot(kind='bar', x='Name', y='Salary')")
print("plt.title('Salaries per Person')")
print("plt.xlabel('Name')")
print("plt.ylabel('Salary (R$)')")
print("plt.xticks(rotation=45)")
print("plt.tight_layout()")
print("plt.show()")
# Out:
# To view the graphs, execute the cells below:
# # Line graph
# plt.figure(figsize=(10, 6))
# plt.plot(df_vis['x'], df_vis['y1'], 'b-', label='Series 1')
# plt.plot(df_vis['x'], df_vis['y2'], 'r--', label='Series 2')
# plt.title('Simple Line Graph')
# plt.xlabel('X-axis')
# plt.ylabel('Y-axis')
# plt.legend()
# plt.grid(True)
# plt.show()
#
# # Graph of bars
# plt.figure(figsize=(10, 6))
# df1.plot(kind='bar', x='Name', y='Salary')
# plt.title('Salaries per Person')
# plt.xlabel('Name')
# plt.ylabel('Salary (R$)')
# plt.xticks(rotation=45)
# plt.tight_layout()
# plt.show()

# %%
# Line Graph
plt.figure(figsize=(10, 6))
plt.plot(df_vis['x'], df_vis['y1'], 'b-', label='Series 1')
plt.plot(df_vis['x'], df_vis['y2'], 'r--', label='Series 2')
plt.title('Simple Line Graph')
plt.xlabel('X-axis')
plt.ylabel('Y-axis')
plt.legend()
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(10, 6))
df1.plot(kind='bar', x='Name', y='Salary')
plt.title('Salaries per Person')
plt.xlabel('Name')
plt.ylabel('Salary (R$)')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
